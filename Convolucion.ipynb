# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Cargamos y visualizamos la imagen de los electrones.
plt.imshow(foto1)
print("La dimensión de la imagen es:", np.shape(foto1))
# Out:
# La dimensión de la imagen es: (224, 224, 3)

# %%
fig,ax = plt.subplots(1,3, figsize = (10,10))
ax[0].imshow(foto1[:,:,0], cmap='Reds')
ax[1].imshow(foto1[:,:,1], cmap='Greens')
ax[2].imshow(foto1[:,:,2], cmap='Blues')
